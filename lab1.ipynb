# %% [markdown]
# # Đọc dữ liệu

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Yêu cầu 1.3

# %%
data = pd.read_csv('train.csv')

# %%
print('Số dòng:', data.shape[0])
print('Các cột:')
print(np.array(data.columns))
# Out:
# Số dòng: 1647
# Các cột:
# ['Make' 'Model' 'Price' 'Year' 'Kilometer' 'Fuel Type' 'Transmission'
#  'Location' 'Color' 'Owner' 'Seller Type' 'Engine' 'Max Power'
#  'Max Torque' 'Drivetrain' 'Length' 'Width' 'Height' 'Seating Capacity'
#  'Fuel Tank Capacity']

# %%
print('5 Dòng đầu tiên của data:')
data.head()
# Out:
# 5 Dòng đầu tiên của data:
#             Make                            Model     Price  Year  Kilometer  \
# 0            BMW                    3-Series 320d    800000  2012      75576
# 1            BMW               X1 sDrive20d xLine   2199000  2016      77000
# 2       Mahindra                   XUV500 W4 1.99    800000  2017     112000
# 3  Mercedes-Benz                  GLS 400d 4MATIC  12900000  2021       3000
# 4         Toyota  Fortuner 2.8 4x2 AT [2016-2020]   3499000  2019      73000
#
#   Fuel Type Transmission     Location   Color   Owner Seller Type   Engine  \
# 0    Diesel    Automatic       Mumbai   White  Second  Individual      NaN
# 1    Diesel    Automatic        Surat   Black   First  Individual  1995 cc
# 2    Diesel       Manual  Muzaffurpur  Silver   First  Individual  1997 cc
# 3    Diesel    Automatic        Delhi   White   First  Individual  2925 cc
# 4    Diesel    Automatic       Mumbai   White   First  Individual  2755 cc
#
#             Max Power         Max Torque Drivetrain  Length   Width  Height  \
# 0                 NaN                NaN        NaN     NaN     NaN     NaN
# 1  184 bhp @ 4000 rpm  350 Nm @ 1750 rpm        RWD  4454.0  2044.0  1545.0
# 2  138 bhp @ 3750 rpm  320 Nm @ 1600 rpm        FWD  4585.0  1890.0  1785.0
# 3  326 bhp @ 3600 rpm  700 Nm @ 1200 rpm        AWD  5207.0  2157.0  1823.0
# 4  174 bhp @ 3400 rpm  450 Nm @ 1600 rpm        RWD  4795.0  1855.0  1835.0
#
#    Seating Capacity  Fuel Tank Capacity
# 0               NaN                 NaN
# 1               5.0                63.0
# 2               7.0                70.0
# 3               7.0                90.0
# 4               7.0                80.0

# %%
def check_catag(name):
    print(data[name].unique().size)
# Out:
# (1647, 20)

# %%
data["Model"].unique().size
# Out:
# 912

# %% [markdown]
# # Data preprocessing

# %%
data.describe()
# Out:
#               Price         Year     Kilometer      Length        Width  \
# count  1.647000e+03  1647.000000  1.647000e+03  1595.00000  1595.000000
# mean   1.696655e+06  2016.419551  5.420636e+04  4281.47837  1767.580564
# std    2.360649e+06     3.370327  5.849584e+04   448.16458   137.053924
# min    4.900000e+04  1988.000000  0.000000e+00  3099.00000  1475.000000
# 25%    4.775000e+05  2014.000000  2.900000e+04  3985.00000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.00000  1775.000000
# 75%    1.950000e+06  2019.000000  7.200000e+04  4630.00000  1835.000000
# max    2.750000e+07  2022.000000  2.000000e+06  5569.00000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1595.000000       1595.000000         1557.000000
# mean   1592.423824          5.310345           52.154656
# std     136.360967          0.816002           15.405199
# min    1165.000000          2.000000           15.000000
# 25%    1485.000000          5.000000           40.000000
# 50%    1550.000000          5.000000           50.000000
# 75%    1675.000000          5.000000           60.000000
# max    1995.000000          8.000000          105.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1647 entries, 0 to 1646
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                1647 non-null   object
#  1   Model               1647 non-null   object
#  2   Price               1647 non-null   int64
#  3   Year                1647 non-null   int64
#  4   Kilometer           1647 non-null   int64
#  5   Fuel Type           1647 non-null   object
#  6   Transmission        1647 non-null   object
#  7   Location            1647 non-null   object
#  8   Color               1647 non-null   object
#  9   Owner               1647 non-null   object
#  10  Seller Type         1647 non-null   object
#  11  Engine              1582 non-null   object
#  12  Max Power           1582 non-null   object
#  13  Max Torque          1582 non-null   object
#  14  Drivetrain          1536 non-null   object
#  15  Length              1595 non-null   float64
#  16  Width               1595 non-null   float64
#  17  Height              1595 non-null   float64
#  18  Seating Capacity    1595 non-null   float64
#  19  Fuel Tank Capacity  1557 non-null   float64
# dtypes: float64(5), int64(3), object(12)
# memory usage: 257.5+ KB

# %%
data["Engine"] = data["Engine"].str.replace(' cc', '', regex=False).astype(float)

# %%
def extract_max_power(power_str):
    if isinstance(power_str, float):
        return np.nan, np.nan
    parts = power_str.split('@')
    bhp_part = parts[0]
    rpm_part = parts[1]
    bhp_value = float(bhp_part.split(' bhp')[0])
    try:
        rpm_value = float(rpm_part.split(' rpm')[0])
    except:
        return bhp_value, np.nan
    return bhp_value, rpm_value

data[['Max Power bhp', 'Max Power rpm']] = data['Max Power'].apply(lambda x: pd.Series(extract_max_power(x)))
data.drop(columns=['Max Power'], inplace=True)

# %%
def extract_max_power(power_str):
    if isinstance(power_str, float):
        return np.nan, np.nan
    parts = power_str.split('@')
    bhp_part = parts[0]
    rpm_part = parts[1]
    bhp_value = float(bhp_part.split(' Nm')[0])
    try:
        rpm_value = float(rpm_part.split(' rpm')[0])
    except:
        return bhp_value, np.nan
    return bhp_value, rpm_value

data[['Max Torque Nm', 'Max Torque rpm']] = data['Max Torque'].apply(lambda x: pd.Series(extract_max_power(x)))
data.drop(columns=['Max Torque'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1647 entries, 0 to 1646
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                1647 non-null   object
#  1   Model               1647 non-null   object
#  2   Price               1647 non-null   int64
#  3   Year                1647 non-null   int64
#  4   Kilometer           1647 non-null   int64
#  5   Fuel Type           1647 non-null   object
#  6   Transmission        1647 non-null   object
#  7   Location            1647 non-null   object
#  8   Color               1647 non-null   object
#  9   Owner               1647 non-null   object
#  10  Seller Type         1647 non-null   object
#  11  Engine              1582 non-null   float64
#  12  Drivetrain          1536 non-null   object
#  13  Length              1595 non-null   float64
#  14  Width               1595 non-null   float64
#  15  Height              1595 non-null   float64
#  16  Seating Capacity    1595 non-null   float64
#  17  Fuel Tank Capacity  1557 non-null   float64
#  18  Max Power bhp       1582 non-null   float64
#  19  Max Power rpm       1578 non-null   float64
#  20  Max Torque Nm       1582 non-null   float64
#  21  Max Torque rpm      1582 non-null   float64
# dtypes: float64(10), int64(3), object(9)
# memory usage: 283.2+ KB

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        data[col].fillna(data[col].mode()[0], inplace=True)
    else:
        data[col].fillna(data[col].median(), inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data["Price"], kde=True, bins=30)
plt.show()

# %%
numeric_data = data.select_dtypes(include=['number'])

# Compute correlation
corr_matrix = numeric_data.corr()

sns.heatmap(corr_matrix, cmap="coolwarm", annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
filtered_corr = corr_matrix[abs(corr_matrix) > 0.3]
plt.figure(figsize=(7, 6))
sns.heatmap(filtered_corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Feature Correlation Heatmap (|corr| > 0.3)")
plt.show()
